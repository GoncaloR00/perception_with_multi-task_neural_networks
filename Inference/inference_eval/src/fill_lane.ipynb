# %%
import cv2

# from google.colab.patches import cv2_imshow


import numpy as np

filePath = './countour.png'
# filePath = './bdd100k/labels/lane/colormaps/val/b1c66a42-6f7d68ca.png'
image = cv2.imread(filePath)
# fazer para cada cor

image = (image != 0) * 255
image = image.astype(np.uint8)

height,width,channel = image.shape

print(channel)

#image = cv2.rotate(image, cv2.cv2.ROTATE_90_CLOCKWISE)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 

cv2.imshow('teste',image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# break

thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 

contour_area = []

for c in contours:

    print('area:', cv2.contourArea(c))

    contour_area.append((cv2.contourArea(c), c))

print('--- contour_area ---')

for item in contour_area:

    print('contour_area:', item[0])

    

# sort list with `(area, contour)` using only `area`    

contour_area = sorted(contour_area, key=lambda x:x[0], reverse=True)

print('--- contour_area - sorted ---')

for item in contour_area:

    print('contour_area:', item[0])

    

# get two the biggest contours    

print('--- two the biggest contours ---')    

print('p0:', contour_area[0][0])

print('p1:', contour_area[1][0])

image2 = np.zeros((height, width, 3), dtype = "uint8")

# draw them


coords1 = np.vstack([contour_area[0][1], contour_area[1][1]])

cv2.fillPoly(image2, [coords1], (255, 255, 255))

gray = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY) 

thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

coords = np.column_stack(np.where(thresh > 0))

c2=np.stack((coords[:,1], coords[:,0]), axis=-1)

cv2.fillPoly(image, [c2], (255, 255, 255))

cv2.imshow('teste2',image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 3
# area: 2008.5
# area: 1684.5
# area: 361.0
# area: 577.0
# area: 552.0
# area: 560.0
# area: 660.5
# area: 677.5
# area: 6742.5
# area: 6757.0
# --- contour_area ---
# contour_area: 2008.5
# contour_area: 1684.5
# contour_area: 361.0
# contour_area: 577.0
# contour_area: 552.0
# contour_area: 560.0
# contour_area: 660.5
# contour_area: 677.5
# contour_area: 6742.5
# contour_area: 6757.0
# --- contour_area - sorted ---
# contour_area: 6757.0
# contour_area: 6742.5
# contour_area: 2008.5
# contour_area: 1684.5
# contour_area: 677.5
# contour_area: 660.5
# contour_area: 577.0
# contour_area: 560.0
# contour_area: 552.0
# contour_area: 361.0
# --- two the biggest contours ---
# p0: 6757.0
# p1: 6742.5

# %%
import cv2
import numpy as np
height, width = 480, 640  # Adjust the size according to your requirements
mask = np.zeros((height, width), dtype=np.uint8)
# Example curve points
curve1 = np.array([[100, 200], [150, 250], [200, 200], [250, 250], [300, 200]], dtype=np.int32)
curve2 = np.array([[100, 220], [150, 270], [200, 220], [250, 270], [300, 220]], dtype=np.int32)
cv2.polylines(mask, [curve1], isClosed=False, color=255, thickness=1)
cv2.polylines(mask, [curve2], isClosed=False, color=255, thickness=1)
# cv2.fillPoly(mask, [curve1, curve2], color=255)
cv2.imshow('Filled Mask', mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# from google.colab.patches import cv2_imshow


import numpy as np

filePath = './countour.png'
# filePath = './bdd100k/labels/lane/colormaps/val/b1c66a42-6f7d68ca.png'
image = cv2.imread(filePath)
# fazer para cada cor

image = (image != 0) * 255
image = image.astype(np.uint8)

height,width,channel = image.shape

print(channel)

#image = cv2.rotate(image, cv2.cv2.ROTATE_90_CLOCKWISE)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 

cv2.imshow('teste',image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# break

thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 

contour_area = []

for c in contours:

    print('area:', cv2.contourArea(c))

    contour_area.append((cv2.contourArea(c), c))

print('--- contour_area ---')

for item in contour_area:

    print('contour_area:', item[0])

    

# sort list with `(area, contour)` using only `area`    

contour_area = sorted(contour_area, key=lambda x:x[0], reverse=True)

print('--- contour_area - sorted ---')

for item in contour_area:

    print('contour_area:', item[0])

    

# get two the biggest contours    

print('--- two the biggest contours ---')    

print('p0:', contour_area[0][0])

print('p1:', contour_area[1][0])

image2 = np.zeros((height, width, 3), dtype = "uint8")

# draw them


coords1 = np.vstack([contour_area[0][1], contour_area[1][1]])

cv2.fillPoly(image2, [coords1], (255, 255, 255))

gray = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY) 

thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

coords = np.column_stack(np.where(thresh > 0))

c2=np.stack((coords[:,1], coords[:,0]), axis=-1)

cv2.fillPoly(image, [c2], (255, 255, 255))

cv2.imshow('teste2',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

def find_if_close(cnt1,cnt2):
    row1,row2 = cnt1.shape[0],cnt2.shape[0]
    for i in range(row1):
        for j in range(row2):
            dist = np.linalg.norm(cnt1[i]-cnt2[j])
            if abs(dist) < 50 :
                return True
            elif i==row1-1 and j==row2-1:
                return False

img = cv2.imread('./bdd100k/labels/lane/colormaps/val/b1c66a42-6f7d68ca.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(gray,127,255,0)
contours,hier = cv2.findContours(thresh,cv2.RETR_EXTERNAL,2)

LENGTH = len(contours)
status = np.zeros((LENGTH,1))

for i,cnt1 in enumerate(contours):
    x = i    
    if i != LENGTH-1:
        for j,cnt2 in enumerate(contours[i+1:]):
            x = x+1
            dist = find_if_close(cnt1,cnt2)
            if dist == True:
                val = min(status[i],status[x])
                status[x] = status[i] = val
            else:
                if status[x]==status[i]:
                    status[x] = i+1

unified = []
maximum = int(status.max())+1
for i in range(maximum):
    pos = np.where(status==i)[0]
    if pos.size != 0:
        cont = np.vstack(contours[i] for i in pos)
        hull = cv2.convexHull(cont)
        unified.append(hull)

img = cv2.drawContours(img,unified,-1,(0,255,0),2)
img =cv2.drawContours(thresh,unified,-1,255,-1)

cv2.imshow('teste2',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# /tmp/ipykernel_101649/1951386839.py:40: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   cont = np.vstack(contours[i] for i in pos)

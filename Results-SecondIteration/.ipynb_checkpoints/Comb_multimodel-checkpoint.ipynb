# %%
models = ['MultiModel-A','MultiModel-B']

# %%
import pandas as pd
table_o = pd.read_excel(models[0]+'.xlsx', sheet_name='Raw', header = [0,1], index_col = [0,1])

# %%
table_o
# Out:
#                                Object detection                         \
#                                    Precision@50 Recall@50 Precision@75
# b1c81faa-3df17267.jpg Drivable              NaN       NaN          NaN
#                       Lane                  NaN       NaN          NaN
# b1c81faa-c80764c5.jpg car                   1.0  0.181818          0.5
#                       Drivable              NaN       NaN          NaN
#                       Lane                  NaN       NaN          NaN
# ...                                         ...       ...          ...
# fe1f2409-c16ea1ed.jpg car                   1.0  0.200000          1.0
#                       Drivable              NaN       NaN          NaN
#                       Lane                  NaN       NaN          NaN
# fe1f55fa-19ba3600.jpg Drivable              NaN       NaN          NaN
#                       Lane                  NaN       NaN          NaN
#
# ...

# %%
table_o[('Object detection', 'Ti')][('b1c81faa-3df17267.jpg', 'Drivable')]
# Out:
# nan

# %%
import math
Ti = math.inf
Tf = 0
for i1, i2 in zip(['Object detection', 'Drivable area', 'Lane marking'], ['car', 'Drivable', 'Lane']):
    val = table_o[(i1, 'Ti')][('b1c81faa-3df17267.jpg', i2)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1013, in Series.__getitem__(self, key)
#    1011 try:
#    1012     # For labels that don't resolve as scalars like tuples and frozensets
# -> 1013     result = self._get_value(key)
#    1015     return result
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/multi.py:2825, in MultiIndex.get_loc(self, key)
#    2824 try:
# -> 2825     return self._engine.get_loc(key)
#    2826 except TypeError:
#    2827     # e.g. test_partial_slicing_with_multiindex partial string slicing
#
# ...
